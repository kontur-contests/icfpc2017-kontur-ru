# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('output.csv')

# %%
data
# Out:
#      Param  rank
# 0     -0.2     0
# 1     -0.4     0
# 2     -0.8     0
# 3     -0.2     0
# 4     -0.6     0
# 5     -0.4     0
# 6     -0.2     0
# 7     -0.4     0
# 8     -0.8     0
# 9     -0.2     0
# 10    -0.6     0
# 11    -0.4     0
# 12    -0.2     0
# 13    -0.4     0
# 14    -0.6     0
# 15    -0.2     0
# 16    -0.4     0
# 17    -0.2     0
# 18    -0.2     0
# 19    -0.4     0
# 20    -0.6     0
# 21    -0.2     0
# 22    -0.4     0
# 23    -0.2     0
# 24    -0.4     0
# 25    -0.6     0
# 26    -0.8   -12
# 27    -0.2     0
# 28    -0.4   -12
# 29    -0.2   -12
# ..     ...   ...
# 270   -0.2     0
# 271   -0.4     0
# 272   -0.6    -3
# 273   -0.2     0
# 274   -0.4    -3
# 275   -0.2    -3
# 276   -0.2     0
# 277   -0.6     0
# 278   -0.8    -3
# 279   -0.4     0
# 280   -0.6    -3
# 281   -0.2    -3
# 282   -0.2    -2
# 283   -0.4     0
# 284   -0.6     0
# 285   -0.2     2
# 286   -0.4     2
# 287   -0.2     0
# 288   -0.2     0
# 289   -0.4     0
# ...

# %%
sns.pairplot(data)
